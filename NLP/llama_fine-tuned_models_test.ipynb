# %%
from spacy_llm.util import assemble

nlp = assemble("config.cfg")
doc = nlp("You look gorgeous!")
print(doc.cats)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 3
#       1 from spacy_llm.util import assemble
# ----> 3 nlp = assemble("config.cfg")
#       4 doc = nlp("You look gorgeous!")
#       5 print(doc.cats)
#
# File ~\Desktop\Aiden-Projects\voc_scraper_nlp_api\venv\Lib\site-packages\spacy_llm\util.py:49, in assemble(config_path, overrides)
#      47 config_path = Path(config_path)
#      48 config = load_config(config_path, overrides=overrides, interpolate=False)
# ---> 49 return assemble_from_config(config)
#
# File ~\Desktop\Aiden-Projects\voc_scraper_nlp_api\venv\Lib\site-packages\spacy_llm\util.py:29, in assemble_from_config(config)
#      23 def assemble_from_config(config: Config) -> Language:
#      24     """Assemble a spaCy pipeline from a confection Config object.
#      25
#      26     config (Config): Config to load spaCy pipeline from.
# ...
